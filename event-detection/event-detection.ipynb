# %%
import pandas as pd
import numpy as np
import string
import nltk
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))
stop_words.update(stopwords.words('french'))
stop_words.update(stopwords.words('german'))
stop_words.update(stopwords.words('italian'))
stop_words.update(string.punctuation)

# %%
columns_name = ['id', 'userId', 'createdAt', 'text', 'longitude', 'latitude', 'placeId', 'inReplyTo', 'source', 'truncated', 'placeLatitude', 'placeLongitude', 'sourceName', 'sourceUrl', 'userName', 'screenName', 'followersCount', 'friendsCount', 'statusesCount', 'userLocation']
tweets = pd.read_csv('../twitter-swisscom/twex_split_1/twex_1.tsv', sep='\t', names=columns_name, na_values='N', header=None)

# %%
stop_words
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'abbia',
#  'abbiamo',
#  'abbiano',
#  'abbiate',
#  'aber',
#  'about',
#  'above',
#  'ad',
#  'after',
#  'again',
#  'against',
#  'agl',
#  'agli',
#  'ai',
#  'aie',
#  'aient',
#  'aies',
#  'ain',
#  'ait',
#  'al',
#  'all',
#  'alla',
#  'alle',
#  'allem',
#  'allen',
#  'aller',
#  'alles',
#  'allo',
#  'als',
#  'also',
#  'am',
#  'an',
#  'anche',
#  'and',
#  'ander',
#  'andere',
#  'anderem',
#  'anderen',
#  'anderer',
#  'anderes',
#  'anderm',
#  'andern',
#  'anderr',
#  'anders',
#  'any',
#  'are',
#  'aren',
#  'as',
#  'at',
#  'au',
#  'auch',
#  'auf',
#  'aura',
#  'aurai',
#  'auraient',
#  'aurais',
#  'aurait',
#  'auras',
#  'aurez',
#  'auriez',
#  'aurions',
#  'aurons',
#  'auront',
#  'aus',
#  'aux',
#  'avaient',
# ...

# %%
tweets.head()
# Out:
#            id      userId            createdAt  \
# 0  9514097914  17341045.0  2010-02-23 05:55:51
# 1  9514846412   7198282.0  2010-02-23 06:22:40
# 2  9516574359  14657884.0  2010-02-23 07:34:25
# 3  9516952605  14703863.0  2010-02-23 07:51:47
# 4  9517198943  14393717.0  2010-02-23 08:02:57
#
#                                                 text longitude latitude  \
# 0                               Guuuuten Morgen! :-)   7.43926  46.9489
# 1  Still the best coffee in town — at La Stanza h...   8.53781  47.3678
# 2  It has been a week or so.. and today I just co...   6.13396  46.1951
# 3         Getting ready..  http://twitpic.com/14v8gz   8.81749  47.2288
# 4  Un peu de réconfort liquide en take away après...   6.63254  46.5199
#
#   placeId inReplyTo source truncated placeLatitude placeLongitude  \
# 0      \N        \N    197                      \N             \N
# 1      \N        \N    550                      \N             \N
# ...
